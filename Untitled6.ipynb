# %% [markdown]
# <a href="https://colab.research.google.com/github/abrarhossam51-max/Phantoms-W2/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

con = sqlite3.connect("store.db")
cursor = con.cursor()


cursor.execute("""
CREATE TABLE IF NOT EXISTS products (
    id INTEGER PRIMARY KEY,
    name TEXT,
    category TEXT,
    price INTEGER
)
""")


products = [
    (1, "Laptop", "Electronics", 30000),
    (2, "Headphones", "Electronics", 5000),
    (3, "T-shirt", "Clothes", 500),
    (4, "Backpack", "Bags", 300),
    (5, "Keyboard", "Electronics", 1500)
]

cursor.executemany("""
INSERT OR IGNORE INTO products (id, name, category, price)
VALUES (?, ?, ?, ?)
""", products)


con.commit()



print("Products in Electronics category:")

cursor.execute("""
SELECT * FROM products
WHERE category = 'Electronics'
""")

electronics_products = cursor.fetchall()

for product in electronics_products:
    print(product)



print("\nProducts sorted by price (highest to lowest):")

cursor.execute("""
SELECT * FROM products
ORDER BY price DESC
""")

sorted_products = cursor.fetchall()

for product in sorted_products:
    print(product)


con.close()
# Out:
# Products in Electronics category:
# (1, 'Laptop', 'Electronics', 30000)
# (2, 'Headphones', 'Electronics', 5000)
# (5, 'Keyboard', 'Electronics', 1500)
#
# Products sorted by price (highest to lowest):
# (1, 'Laptop', 'Electronics', 30000)
# (2, 'Headphones', 'Electronics', 5000)
# (5, 'Keyboard', 'Electronics', 1500)
# (3, 'T-shirt', 'Clothes', 500)
# (4, 'Backpack', 'Bags', 300)
